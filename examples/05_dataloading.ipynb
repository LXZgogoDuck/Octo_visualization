# %% [markdown]
# # Octo Dataloading Examples
#
# This notebook will walk you through some of the primary features of the Octo dataloader. Data is, after all, the most important part of any machine learning pipeline!

# %% [markdown]
# ## Loading Open X-Embodiment Data
#
# The [Open X-Embodiment (OXE)](https://robotics-transformer-x.github.io/) project was a massive cross-instutition data collection collaboration the likes of which robot learning has never seen before. The resulting dataset includes 22 different robots demonstrating 527 skills and totals over 1 million trajectories. However, as we found throughout the course of the Octo project, simply loading such a diverse set of robot data is no small feat. We hope that the `octo.data` pipeline can help kickstart anyone who hopes to take advantage of the massive collection of robot demonstrations that is OXE!
#
# ### Minimum working example to load a single OXE dataset

# %%
# minimum working example to load a single OXE dataset
from octo.data.oxe import make_oxe_dataset_kwargs
from octo.data.dataset import make_single_dataset

dataset_kwargs = make_oxe_dataset_kwargs(
    # see octo/data/oxe/oxe_dataset_configs.py for available datasets
    # (this is a very small one for faster loading)
    "austin_buds_dataset_converted_externally_to_rlds",
    # can be local or on cloud storage (anything supported by TFDS)
    # "/path/to/base/oxe/directory",
    "gs://gresearch/robotics",
)
dataset = make_single_dataset(dataset_kwargs, train=True) # load the train split
iterator = dataset.iterator()
# Out:
# 2025-02-18 19:54:26.605512: W external/local_tsl/tsl/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "FAILED_PRECONDITION: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Could not resolve host: metadata.google.internal".
# WARNING:tensorflow:AutoGraph could not transform <function _gcd_import at 0x10066b400> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x10066b400>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function _gcd_import at 0x10066b400> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x10066b400>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function _gcd_import at 0x10066b400> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x10066b400>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 50it [04:12,  5.05s/it]
# WARNING:root:Could not write dataset statistics to gs://gresearch/robotics/austin_buds_dataset_converted_externally_to_rlds/0.1.0/dataset_statistics_d48760d6a9aba075176e892dab18f982ee4f88367ac314a7136835130124481a.json. Writing to /Users/fairyliu/.cache/octo/dataset_statistics_d48760d6a9aba075176e892dab18f982ee4f88367ac314a7136835130124481a.json instead.
# WARNING:absl:No resize_size was provided for image_primary. This will result in 1x1 padding images, which may cause errors if you mix padding and non-padding images.

# %%
# make_single_dataset yields entire trajectories
traj = next(iterator)
print("Top-level keys: ", traj.keys())
print("Observation keys: ", traj["observation"].keys())
print("Task keys: ", traj["task"].keys())
# Out:
# Top-level keys:  dict_keys(['observation', 'task', 'action', 'dataset_name', 'action_pad_mask'])
# Observation keys:  dict_keys(['image_primary', 'timestep', 'pad_mask_dict', 'timestep_pad_mask', 'task_completed'])
# Task keys:  dict_keys(['language_instruction', 'pad_mask_dict'])

# %%
from PIL import Image
import numpy as np

traj = next(iterator)
images = traj["observation"]["image_primary"]
# should be: (traj_len, window_size, height, width, channels)
# (window_size defaults to 1)
print(images.shape)  
Image.fromarray(np.concatenate(images.squeeze()[-5:], axis=1))
# Out:
# (746, 1, 128, 128, 3)
# <PIL.Image.Image image mode=RGB size=640x128>

# %%
# you should set these much higher in practice (as large as your memory can hold!)
SHUFFLE_BUFFER_SIZE = 1000
BATCH_SIZE = 64

# turning a dataset of trajectories into a training-ready batched dataset
train_dataset = (
    dataset.flatten() # flattens trajectories into individual frames
    .shuffle(SHUFFLE_BUFFER_SIZE) # shuffles the frames
    .batch(BATCH_SIZE) # batches the frames
)
batch = next(train_dataset.iterator())
images = batch["observation"]["image_primary"]
# should be: (batch_size, window_size, height, width, channels)
print(images.shape)
Image.fromarray(np.concatenate(images.squeeze()[:5], axis=1))
# Out:
# (64, 1, 128, 128, 3)
# <PIL.Image.Image image mode=RGB size=640x128>

# %% [markdown]
# ### Loading a training-ready OXE mix
#
# In reality, you're probably going to want to mix multiple datasets together, as well as use other transformations such as resizing, augmentation, windowing, etc. This section will show you how to get a proper OXE mix up and running, as well as demonstrate additional `octo.data` features for more realistic use-cases.

# %%
from octo.data.oxe import make_oxe_dataset_kwargs_and_weights
from octo.data.dataset import make_interleaved_dataset

dataset_kwargs_list, sample_weights = make_oxe_dataset_kwargs_and_weights(
    # you can pass your own list of dataset names and sample weights here, but we've
    # also provided a few named mixes for convenience. The Octo model was trained
    # using the "oxe_magic_soup" mix.
    "rtx",
    # can be local or on cloud storage (anything supported by TFDS)
    "gs://gresearch/robotics",
    # let's get a wrist camera!
    load_camera_views=("primary", "wrist"),
)

# see `octo.data.dataset.make_dataset_from_rlds` for the meaning of these kwargs
dataset_kwargs_list[0]
# Out:
# {'name': 'fractal20220817_data',
#  'data_dir': 'gs://gresearch/robotics',
#  'image_obs_keys': {'primary': 'image', 'wrist': None},
#  'action_normalization_mask': [True, True, True, True, True, True, False],
#  'language_key': 'language_instruction',
#  'action_proprio_normalization_type': <NormalizationType.NORMAL: 'normal'>,
#  'standardize_fn': {'module': 'octo.data.oxe.oxe_standardization_transforms',
#   'name': 'rt1_dataset_transform',
#   'args': (),
#   'kwargs': {}}}

# %%
SHUFFLE_BUFFER_SIZE = 1000
BATCH_SIZE = 8

# each element of `dataset_kwargs_list` can be used with `make_single_dataset`, but let's
# use the more powerful `make_interleaved_dataset` to combine them for us!
dataset = make_interleaved_dataset(
    dataset_kwargs_list,
    sample_weights,
    train=True,
    # unlike our manual shuffling above, `make_interleaved_dataset` will shuffle
    # the JPEG-encoded images, so you should be able to fit a much larger buffer size
    shuffle_buffer_size=SHUFFLE_BUFFER_SIZE,
    batch_size=BATCH_SIZE,
    # see `octo.data.dataset.apply_trajectory_transforms` for full documentation
    # of these configuration options
    traj_transform_kwargs=dict(
        goal_relabeling_strategy="uniform",  # let's get some goal images
        window_size=2,  # let's get some history
        action_horizon=4,  # let's get some future actions for action chunking
        subsample_length=100,  # subsampling long trajectories improves shuffling a lot
    ),
    # see `octo.data.dataset.apply_frame_transforms` for full documentation
    # of these configuration options
    frame_transform_kwargs=dict(
        # let's apply some basic image augmentations -- see `dlimp.transforms.augment_image`
        # for full documentation of these configuration options
        image_augment_kwargs=dict(
            primary=dict(
                augment_order=["random_resized_crop", "random_brightness"],
                random_resized_crop=dict(scale=[0.8, 1.0], ratio=[0.9, 1.1]),
                random_brightness=[0.1],
            )
        ),
        # providing a `resize_size` is highly recommended for a mixed dataset, otherwise
        # datasets with different resolutions will cause errors
        resize_size=dict(
            primary=(256, 256),
            wrist=(128, 128),
        ),
        # If parallelism options are not provided, they will default to tf.Data.AUTOTUNE.
        # However, we would highly recommend setting them manually if you run into issues
        # with memory or dataloading speed. Frame transforms are usually the speed
        # bottleneck (due to image decoding, augmentation, and resizing), so you can set
        # this to a very high value if you have a lot of CPU cores. Keep in mind that more
        # parallel calls also use more memory, though.
        num_parallel_calls=64,
    ),
    # Same spiel as above about performance, although trajectory transforms and data reading
    # are usually not the speed bottleneck. One reason to manually set these is if you want
    # to reduce memory usage (since autotune may spawn way more threads than necessary).
    traj_transform_threads=16,
    traj_read_threads=16,
)

# Another performance knob to tune is the number of batches to prefetch -- again,
# the default of tf.data.AUTOTUNE can sometimes use more memory than necessary.
iterator = dataset.iterator(prefetch=1)
# Out:
# 8908it [24:20, 12.85it/s]2025-02-18 20:40:32.348797: E external/local_tsl/tsl/platform/cloud/curl_http_request.cc:611] The transmission  of request 0x351f0eca0 (URI: https://storage.googleapis.com/gresearch/robotics%2Ffractal20220817_data%2F0.1.0%2Ffractal20220817_data-train.tfrecord-00110-of-01024) has been stuck at 43446648 of 67108864 bytes for 61 seconds and will be aborted. CURL timing information: lookup time: 0.002482 (No error), connect time: 0.009397 (No error), pre-transfer time: 0.038304 (No error), start-transfer time: 0.368523 (No error)
# 2025-02-18 20:40:32.354686: E external/local_tsl/tsl/platform/cloud/curl_http_request.cc:611] The transmission  of request 0x35aa082e0 (URI: https://storage.googleapis.com/gresearch/robotics%2Ffractal20220817_data%2F0.1.0%2Ffractal20220817_data-train.tfrecord-00111-of-01024) has been stuck at 34765514 of 67108864 bytes for 61 seconds and will be aborted. CURL timing information: lookup time: 0.003656 (No error), connect time: 0.011397 (No error), pre-transfer time: 0.041559 (No error), start-transfer time: 0.319081 (No error)
# 2025-02-18 20:40:32.380106: E external/local_tsl/tsl/platform/cloud/curl_http_request.cc:611] The transmission  of request 0x1320ef470 (URI: https://storage.googleapis.com/gresearch/robotics%2Ffractal20220817_data%2F0.1.0%2Ffractal20220817_data-train.tfrecord-00104-of-01024) has been stuck at 33323713 of 67108864 bytes for 61 seconds and will be aborted. CURL timing information: lookup time: 0.002516 (No error), connect time: 0.00837 (No error), pre-transfer time: 0.034806 (No error), start-transfer time: 0.652191 (No error)
# 2025-02-18 20:40:32.413334: E external/local_tsl/tsl/platform/cloud/curl_http_request.cc:611] The transmission  of request 0x35811cc00 (URI: https://storage.googleapis.com/gresearch/robotics%2Ffractal20220817_data%2F0.1.0%2Ffractal20220817_data-train.tfrecord-00105-of-01024) has been stuck at 26932102 of 49479801 bytes for 61 seconds and will be aborted. CURL timing information: lookup time: 0.001455 (No error), connect time: 0.007514 (No error), pre-transfer time: 0.056004 (No error), start-transfer time: 0.534905 (No error)
# 2025-02-18 20:40:32.432456: E external/local_tsl/tsl/platform/cloud/curl_http_request.cc:611] The transmission  of request 0x35ab3a220 (URI: https://storage.googleapis.com/gresearch/robotics%2Ffractal20220817_data%2F0.1.0%2Ffractal20220817_data-train.tfrecord-00112-of-01024) has been stuck at 31439568 of 67108864 bytes for 61 seconds and will be aborted. CURL timing information: lookup time: 0.015292 (No error), connect time: 0.052121 (No error), pre-transfer time: 0.082102 (No error), start-transfer time: 0.406777 (No error)
# 2025-02-18 20:40:32.528554: E external/local_tsl/tsl/platform/cloud/curl_http_request.cc:611] The transmission  of request 0x3247e5780 (URI: https://storage.googleapis.com/gresearch/robotics%2Ffractal20220817_data%2F0.1.0%2Ffractal20220817_data-train.tfrecord-00106-of-01024) has been stuck at 41925314 of 52301055 bytes for 61 seconds and will be aborted. CURL timing information: lookup time: 0.004262 (No error), connect time: 0.021304 (No error), pre-transfer time: 0.056565 (No error), start-transfer time: 0.245877 (No error)
# 8964it [27:12,  5.49it/s]
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# Cell In[6], line 6
#       2 BATCH_SIZE = 8
#       4 # each element of `dataset_kwargs_list` can be used with `make_single_dataset`, but let's
#       5 # use the more powerful `make_interleaved_dataset` to combine them for us!
# ----> 6 dataset = make_interleaved_dataset(
#       7     dataset_kwargs_list,
#       8     sample_weights,
#       9     train=True,
#      10     # unlike our manual shuffling above, `make_interleaved_dataset` will shuffle
#      11     # the JPEG-encoded images, so you should be able to fit a much larger buffer size
#      12     shuffle_buffer_size=SHUFFLE_BUFFER_SIZE,
#      13     batch_size=BATCH_SIZE,
#      14     # see `octo.data.dataset.apply_trajectory_transforms` for full documentation
#      15     # of these configuration options
#      16     traj_transform_kwargs=dict(
#      17         goal_relabeling_strategy="uniform",  # let's get some goal images
#      18         window_size=2,  # let's get some history
#      19         action_horizon=4,  # let's get some future actions for action chunking
#      20         subsample_length=100,  # subsampling long trajectories improves shuffling a lot
#      21     ),
#      22     # see `octo.data.dataset.apply_frame_transforms` for full documentation
#      23     # of these configuration options
#      24     frame_transform_kwargs=dict(
#      25         # let's apply some basic image augmentations -- see `dlimp.transforms.augment_image`
#      26         # for full documentation of these configuration options
#      27         image_augment_kwargs=dict(
#      28             primary=dict(
#      29                 augment_order=["random_resized_crop", "random_brightness"],
#      30                 random_resized_crop=dict(scale=[0.8, 1.0], ratio=[0.9, 1.1]),
#      31                 random_brightness=[0.1],
#      32             )
#      33         ),
#      34         # providing a `resize_size` is highly recommended for a mixed dataset, otherwise
#      35         # datasets with different resolutions will cause errors
#      36         resize_size=dict(
#      37             primary=(256, 256),
#      38             wrist=(128, 128),
#      39         ),
#      40         # If parallelism options are not provided, they will default to tf.Data.AUTOTUNE.
#      41         # However, we would highly recommend setting them manually if you run into issues
#      42         # with memory or dataloading speed. Frame transforms are usually the speed
#      43         # bottleneck (due to image decoding, augmentation, and resizing), so you can set
#      44         # this to a very high value if you have a lot of CPU cores. Keep in mind that more
#      45         # parallel calls also use more memory, though.
#      46         num_parallel_calls=64,
#      47     ),
#      48     # Same spiel as above about performance, although trajectory transforms and data reading
#      49     # are usually not the speed bottleneck. One reason to manually set these is if you want
#      50     # to reduce memory usage (since autotune may spawn way more threads than necessary).
#      51     traj_transform_threads=16,
#      52     traj_read_threads=16,
#      53 )
#      55 # Another performance knob to tune is the number of batches to prefetch -- again,
#      56 # the default of tf.data.AUTOTUNE can sometimes use more memory than necessary.
#      57 iterator = dataset.iterator(prefetch=1)
#
# File ~/PycharmProjects/HN-LoRA1/octo/data/dataset.py:562, in make_interleaved_dataset(dataset_kwargs_list, sample_weights, train, shuffle_buffer_size, traj_transform_kwargs, frame_transform_kwargs, batch_size, balance_weights, traj_transform_threads, traj_read_threads)
#     560 all_dataset_statistics = {}
#     561 for dataset_kwargs in dataset_kwargs_list:
# --> 562     _, dataset_statistics = make_dataset_from_rlds(**dataset_kwargs, train=train)
#     563     dataset_sizes.append(dataset_statistics["num_transitions"])
#     564     assert (
#     565         dataset_kwargs["name"] not in all_dataset_statistics
#     566     ), f"Duplicate name {dataset_kwargs['name']}"
#
# File ~/PycharmProjects/HN-LoRA1/octo/data/dataset.py:423, in make_dataset_from_rlds(name, data_dir, train, standardize_fn, shuffle, image_obs_keys, depth_obs_keys, proprio_obs_key, language_key, action_proprio_normalization_type, dataset_statistics, force_recompute_dataset_statistics, action_normalization_mask, filter_functions, skip_norm, ignore_errors, num_parallel_reads, num_parallel_calls)
#     421     full_dataset = full_dataset.traj_map(restructure).filter(is_nonzero_length)
#     422     # tries to load from cache, otherwise computes on the fly
# --> 423     dataset_statistics = get_dataset_statistics(
#     424         full_dataset,
#     425         hash_dependencies=(
#     426             str(builder.info),
#     427             str(proprio_obs_key),
#     428             ModuleSpec.to_string(standardize_fn)
#     429             if standardize_fn is not None
#     430             else "",
#     431             *map(ModuleSpec.to_string, filter_functions),
#     432         ),
#     433         save_dir=builder.data_dir,
#     434         force_recompute=force_recompute_dataset_statistics,
#     435     )
#     436 dataset_statistics = tree_map(np.array, dataset_statistics)
#     438 # skip normalization for certain action dimensions
#
# File ~/PycharmProjects/HN-LoRA1/octo/data/utils/data_utils.py:147, in get_dataset_statistics(dataset, hash_dependencies, save_dir, force_recompute)
#     145 num_transitions = 0
#     146 num_trajectories = 0
# --> 147 for traj in tqdm.tqdm(
#     148     dataset.iterator(),
#     149     total=cardinality if cardinality != tf.data.UNKNOWN_CARDINALITY else None,
#     150 ):
#     151     actions.append(traj["action"])
#     152     if "proprio" in traj:
#
# File ~/miniconda3/lib/python3.10/site-packages/tqdm/std.py:1195, in tqdm.__iter__(self)
#    1192 time = self._time
#    1194 try:
# -> 1195     for obj in iterable:
#    1196         yield obj
#    1197         # Update and possibly print the progressbar.
#    1198         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:4788, in NumpyIterator.__next__(self)
#    4785     numpy.setflags(write=False)
#    4786   return numpy
# -> 4788 return nest.map_structure(to_numpy, next(self._iterator))
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:826, in OwnedIterator.__next__(self)
#     824 def __next__(self):
#     825   try:
# --> 826     return self._next_internal()
#     827   except errors.OutOfRangeError:
#     828     raise StopIteration
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:776, in OwnedIterator._next_internal(self)
#     773 # TODO(b/77291417): This runs in sync mode as iterators use an error status
#     774 # to communicate that there is no more data to iterate over.
#     775 with context.execution_mode(context.SYNC):
# --> 776   ret = gen_dataset_ops.iterator_get_next(
#     777       self._iterator_resource,
#     778       output_types=self._flat_output_types,
#     779       output_shapes=self._flat_output_shapes)
#     781   try:
#     782     # Fast path for the case `self._structure` is not a nested structure.
#     783     return self._element_spec._from_compatible_tensor_list(ret)  # pylint: disable=protected-access
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3086, in iterator_get_next(iterator, output_types, output_shapes, name)
#    3084   return _result
#    3085 except _core._NotOkStatusException as e:
# -> 3086   _ops.raise_from_not_ok_status(e, name)
#    3087 except _core._FallbackException:
#    3088   pass
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:6002, in raise_from_not_ok_status(e, name)
#    6000 def raise_from_not_ok_status(e, name) -> NoReturn:
#    6001   e.message += (" name: " + str(name if name is not None else ""))
# -> 6002   raise core._status_to_exception(e) from None
#
# FailedPreconditionError: {{function_node __wrapped__IteratorGetNext_output_types_1_device_/job:localhost/replica:0/task:0/device:CPU:0}} Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Could not resolve host: storage.googleapis.com
# 	 when reading gs://gresearch/robotics/fractal20220817_data/0.1.0/fractal20220817_data-train.tfrecord-00104-of-01024 [Op:IteratorGetNext] name:

# %%
# phew, that was a lot of configuration! Let's see what we got.
batch = next(iterator)
print("Top-level keys: ", batch.keys())
# should now have "image_primary" and "image_wrist"!
print("Observation keys: ", batch["observation"].keys())
# should also have "image_primary" and "image_wrist", corresponding to future goal images
print("Task keys: ", batch["task"].keys())
# Out:
# Top-level keys:  dict_keys(['observation', 'task', 'action', 'dataset_name', 'action_pad_mask'])
# Observation keys:  dict_keys(['image_primary', 'timestep', 'pad_mask_dict', 'timestep_pad_mask', 'task_completed'])
# Task keys:  dict_keys(['language_instruction', 'pad_mask_dict'])

# %%
from PIL import Image
import numpy as np

images_primary = batch["observation"]["image_primary"]
images_wrist = batch["observation"]["image_wrist"]
# should be: (batch_size, window_size (now 2), height, width, channels)
print(images_primary.shape)
print(images_wrist.shape)
actions = batch["action"]
# should be: (batch_size, window_size, action_horizon, action_dim)
print(actions.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 5
#       2 import numpy as np
#       4 images_primary = batch["observation"]["image_primary"]
# ----> 5 images_wrist = batch["observation"]["image_wrist"]
#       6 # should be: (batch_size, window_size (now 2), height, width, channels)
#       7 print(images_primary.shape)
#
# KeyError: 'image_wrist'

# %%
# let's visualize a window of primary images
display(Image.fromarray(np.concatenate(images_primary[0], axis=1)))
# now a window of wrist images -- many datasets don't have wrist images,
# so this will often be black
display(Image.fromarray(np.concatenate(images_wrist[0], axis=1)))
# pad_mask_dict also tells you which keys should be treated as padding
# (e.g., if the wrist camera is black, the corresponding pad_mask_dict entry is False)
print(batch["observation"]["pad_mask_dict"]["image_wrist"][0])
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       2 display(Image.fromarray(np.concatenate(images_primary[0], axis=1)))
#       3 # now a window of wrist images -- many datasets don't have wrist images,
#       4 # so this will often be black
# ----> 5 display(Image.fromarray(np.concatenate(images_wrist[0], axis=1)))
#       6 # pad_mask_dict also tells you which keys should be treated as padding
#       7 # (e.g., if the wrist camera is black, the corresponding pad_mask_dict entry is False)
#       8 print(batch["observation"]["pad_mask_dict"]["image_wrist"][0])
#
# NameError: name 'images_wrist' is not defined

# %%
# let's take a look at the "task" dict: it should now have both goal
# images and language instructions!
goal_primary = batch["task"]["image_primary"]
goal_wrist = batch["task"]["image_wrist"]
language_instruction = batch["task"]["language_instruction"]
display(Image.fromarray(goal_primary[0]))
display(Image.fromarray(goal_wrist[0]))
print(language_instruction[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 3
#       1 # let's take a look at the "task" dict: it should now have both goal
#       2 # images and language instructions!
# ----> 3 goal_primary = batch["task"]["image_primary"]
#       4 goal_wrist = batch["task"]["image_wrist"]
#       5 language_instruction = batch["task"]["language_instruction"]
#
# KeyError: 'image_primary'
